# %%
# !git clone https://github.com/HarshAggarwal524/sourcerer.git
# %cd sourcerer
# Out:
# fatal: destination path 'sourcerer' already exists and is not an empty directory.
# /content/sourcerer

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 378.1/378.1 kB 9.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.3/611.3 kB 46.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 78.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 12.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 85.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 92.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: sentence-transformers
#     Found existing installation: sentence-transformers 5.6.0
#     Uninstalling sentence-transformers-5.6.0:
#       Successfully uninstalled sentence-transformers-5.6.0
# ...

# %%
# !pip install -r requirements.txt

# %%
# !sed -i 's|/Users/harshaggarwal/Projects_4/sourcerer/data/testpdf.pdf|data/testpdf.pdf|g' main.py eval/score.py
# !grep -n "pdf_path\|PDF_PATH" main.py eval/score.py
# Out:
# main.py:14:def get_store_path(pdf_path, model_name):
# main.py:15:    with open(pdf_path, "rb") as f:
# main.py:22:def load_or_build(pdf_path, model_name=MODEL_NAME):
# main.py:23:    store_path = get_store_path(pdf_path, model_name)
# main.py:32:    text = extract_text(pdf_path)
# main.py:50:    pdf_path = "data/testpdf.pdf"
# main.py:53:        chunks, embeddings = load_or_build(pdf_path)
# main.py:58:    print(f"\nReady. Loaded {len(chunks)} chunks from {pdf_path}.")
# eval/score.py:7:PDF_PATH = "data/testpdf.pdf"
# eval/score.py:73:    chunks, embeddings = load_or_build(PDF_PATH)

# %%
from google.colab import userdata
import os
os.environ["GROQ_API_KEY"] = userdata.get("GROQ_API_KEY")

# %%
# !ls data/
# Out:
# ls: cannot access 'data/': No such file or directory

# %%
# !ls data/
# Out:
# ls: cannot access 'data/': No such file or directory

# %%
# !pwd
# !ls
# Out:
# /content/sourcerer
# app.py	debug_output.txt  decisions.md	eval  main.py  requirements.txt  src

# %%
# !mkdir -p data

# %%
# !ls data/
# Out:
# testpdf.pdf

# %%
# !python3 -m eval.score
# Out:
# modules.json: 100% 349/349 [00:00<00:00, 2.01MB/s]
# config_sentence_transformers.json: 100% 116/116 [00:00<00:00, 579kB/s]
# ...
# README.md: 100% 10.5k/10.5k [00:00<00:00, 30.2MB/s]
# sentence_bert_config.json: 100% 53.0/53.0 [00:00<00:00, 299kB/s]
# config.json: 100% 612/612 [00:00<00:00, 3.27MB/s]
#
# model.safetensors: downloading bytes:  83% 75.5M/90.9M [00:01<00:00, 131MB/s, 4.71MB/s  ]
# model.safetensors: downloading bytes: 100% 85.0M/85.0M [00:01<00:00, 72.5MB/s, 8.18MB/s  ]
# model.safetensors: reconstructing file: 100% 90.9M/90.9M [00:01<00:00, 77.5MB/s, 8.83MB/s  ]
# Loading weights: 100% 103/103 [00:00<00:00, 5384.35it/s]
# tokenizer_config.json: 100% 350/350 [00:00<00:00, 2.39MB/s]
# vocab.txt: 100% 232k/232k [00:00<00:00, 15.4MB/s]
# tokenizer.json: 100% 466k/466k [00:00<00:00, 46.1MB/s]
# special_tokens_map.json: 100% 112/112 [00:00<00:00, 506kB/s]
# config.json: 100% 190/190 [00:00<00:00, 1.30MB/s]
# config.json: 100% 795/795 [00:00<00:00, 4.95MB/s]
#
# ...

# %%
# !mkdir -p cache

# %%
# !python3 -m eval.score
# Out:
# ...
# Loading weights: 100% 103/103 [00:00<00:00, 5044.35it/s]
# Loading weights: 100% 393/393 [00:00<00:00, 8677.64it/s]
# No cache found for this PDF + model — processing for the first time...
# Saved new cache: cache/store_63646eb77a100482.pkl
# Loaded 33 chunks.
#
# ========== STAGE 2: Hybrid (BM25 + Vector + RRF) ==========
#
# --- Easy set (Stage 2) (30 questions) ---
# Recall@3: 0.9667
# MRR: 0.8881
#
# --- Hard set (Stage 2) (29 questions) ---
# Recall@3: 0.7931
# MRR: 0.7322
#
# --- Hardest set (Stage 2) (22 questions) ---
# Recall@3: 0.5909
# MRR: 0.5735
#
# --- Ambiguous Experimental set (Stage 2) (29 questions) ---
# Recall@3: 0.5172
# MRR: 0.5037
#
# ========== STAGE 3: + Reranking ==========
#
# --- Easy set (Stage 3) (30 questions) ---
# Recall@3: 1.0000
# MRR: 1.0000
#
# --- Hard set (Stage 3) (29 questions) ---
# Recall@3: 0.9310
# MRR: 0.9262
#
# --- Hardest set (Stage 3) (22 questions) ---
# Recall@3: 0.9091
# MRR: 0.8157
#
# ...
